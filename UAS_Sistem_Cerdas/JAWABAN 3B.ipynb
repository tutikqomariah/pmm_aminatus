# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
df = pd.read_csv('D:/STIMATA/SEMESTER 7/SISTEM CERDAS/UAS_SISTEM_CERDAS_SPADA/dataset_UAS-main/dataset_soal No. 3.txt',delimiter=',')

# %%
df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian
# 0           0
# 1           1
# 2           0
# 3           0
# ...

# %%
import math 
dis = []
for i in range(80):
    dis.append(math.sqrt((float(df.iloc[i]['Usia'])-29)**2
                         +(float(df.iloc[i]['Kelahiran_ke-'])- 2)**2
                         +(float(df.iloc[i]['Waktu_Kelahiran'])-0)**2
                         +(float(df.iloc[i]['Tekanan_darah'])-2)**2))

# %%
df['dis'] = dis
df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian       dis
# 0           0  7.071068
# 1           1  3.162278
# ...

# %%
df.sort_values('dis')
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 54    29              2                0              1                 1
# 77    29              2                1              2                 0
# 67    29              2                0              1                 1
# 59    30              2                1              2                 1
# 3     28              1                0              2                 0
# ..   ...            ...              ...            ...               ...
# 61    19              1                0              1                 0
# 26    18              1                1              2                 1
# 31    40              1                0              1                 1
# 25    18              1                0              1                 0
# 70    17              1                0              0                 0
#
#     Caesarian        dis
# 54          1   1.000000
# 77          1   1.000000
# ...

# %%
y = df.sort_values('dis').head(5)
y
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 54    29              2                0              1                 1
# 77    29              2                1              2                 0
# 67    29              2                0              1                 1
# 59    30              2                1              2                 1
# 3     28              1                0              2                 0
#
#     Caesarian       dis
# 54          1  1.000000
# 77          1  1.000000
# 67          0  1.000000
# 59          1  1.414214
# 3           0  1.414214

# %%
z = y["Caesarian"]
z
# Out:
# 54    1
# 77    1
# 67    0
# 59    1
# 3     0
# Name: Caesarian, dtype: int64

# %%
np.mean(z)
# Out:
# 0.6

# %%
df.to_excel('D:/STIMATA/SEMESTER 7/SISTEM CERDAS/UAS_SISTEM_CERDAS_SPADA/Outputs_KNN_Nomer3b.xls')
# Out:
# <ipython-input-14-699a5b5f1277>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('D:/STIMATA/SEMESTER 7/SISTEM CERDAS/UAS_SISTEM_CERDAS_SPADA/Outputs_KNN_Nomer3b.xls')
